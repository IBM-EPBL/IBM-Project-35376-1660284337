# %%
import pandas as pd
 import seaborn as sns
  import numpy as np 
from matplotlib 
import pyplot as plt 
# %matplotlib inline
# Out:
#   File "<ipython-input-2-3b5137dda458>", line 2
#     import seaborn as sns
#     ^
# IndentationError: unexpected indent
